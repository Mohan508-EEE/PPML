# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A': ['sai', 'poo', 'sub', 'yuvi', 'rithi', 'sangu'],
'B': ['one', 'two', 'three', 'one', 'three', 'two'],
'C': np.random.randint(5, size=6),
'D': np.random.randint(5, size=6),
'E': np.random.randint(5, size=6)})
print("\nOriginal DataFrame\n",df)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  0  3  0
# 1    poo    two  0  1  0
# 2    sub  three  1  4  4
# 3   yuvi    one  4  0  2
# 4  rithi  three  1  4  0
# 5  sangu    two  3  3  2

# %%
#Aggregate function to produce sum,min and max
a=df.agg(['sum', 'min', 'max'])
print("\nOriginal DataFrame\n",df)
print("\nAggregate function to produce sum, min and max\n",a)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  0  3  0
# 1    poo    two  0  1  0
# 2    sub  three  1  4  4
# 3   yuvi    one  4  0  2
# 4  rithi  three  1  4  0
# 5  sangu    two  3  3  2
#
# Aggregate function to produce sum, min and max
#                             A                       B  C   D  E
# sum  saipoosubyuvirithisangu  onetwothreeonethreetwo  9  15  8
# min                      poo                     one  0   0  0
# max                     yuvi                     two  4   4  4

# %%
#Different aggregation per column
b=df.agg({'A': ['sum', 'min'], 'B': ['min', 'max']})
print("\nOriginal DataFrame\n",df)
print("\nDifferent aggregations per column\n",b)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  0  3  0
# 1    poo    two  0  1  0
# 2    sub  three  1  4  4
# 3   yuvi    one  4  0  2
# 4  rithi  three  1  4  0
# 5  sangu    two  3  3  2
#
# Different aggregations per column
#                             A    B
# sum  saipoosubyuvirithisangu  NaN
# min                      poo  one
# max                      NaN  two

# %%
#Aggregate different functions over the columns and rename the index of the resulting DataFrame
c=df.agg(x=('A', max), y=('B', 'min'), z=('C', np.mean))
print("\nOriginal DataFrame\n",df)
print("\nAggregate different functions over the columns and rename the index of the resulting DataFrame\n",c)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  0  3  0
# 1    poo    two  0  1  0
# 2    sub  three  1  4  4
# 3   yuvi    one  4  0  2
# 4  rithi  three  1  4  0
# 5  sangu    two  3  3  2
#
# Aggregate different functions over the columns and rename the index of the resulting DataFrame
#        A    B    C
# x  yuvi  NaN  NaN
# y   NaN  one  NaN
# z   NaN  NaN  1.5
# /tmp/ipykernel_7786/2560020860.py:2: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   c=df.agg(x=('A', max), y=('B', 'min'), z=('C', np.mean))
# /tmp/ipykernel_7786/2560020860.py:2: FutureWarning: The provided callable <function mean at 0x7ed90c7254e0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   c=df.agg(x=('A', max), y=('B', 'min'), z=('C', np.mean))

# %%
#Aggregate over the rows (only numeric columns)
d=df.select_dtypes(include=np.number).agg("sum", axis="columns")
print("\nOriginal DataFrame\n",df)
print("\nAggregate-Sum: row wise (numeric columns only)\n",d)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  0  3  0
# 1    poo    two  0  1  0
# 2    sub  three  1  4  4
# 3   yuvi    one  4  0  2
# 4  rithi  three  1  4  0
# 5  sangu    two  3  3  2
#
# Aggregate-Sum: row wise (numeric columns only)
#  0    3
# 1    1
# 2    9
# 3    6
# 4    5
# 5    8
# dtype: int64

# %%
#Aggregate over the columns
e=df.agg("sum", axis="rows")
print("\nOriginal DataFrame\n",df)
print("\nAggregate-Sum: Column wise\n", e)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  0  3  0
# 1    poo    two  0  1  0
# 2    sub  three  1  4  4
# 3   yuvi    one  4  0  2
# 4  rithi  three  1  4  0
# 5  sangu    two  3  3  2
#
# Aggregate-Sum: Column wise
#  A    saipoosubyuvirithisangu
# B     onetwothreeonethreetwo
# C                          9
# D                         15
# E                          8
# dtype: object

# %%
#Summary of aggregate function using describe
print("\nOriginal DataFrame\n",df)

print("\nSummary of aggregate functions using describe()\n",df.describe())
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  0  3  0
# 1    poo    two  0  1  0
# 2    sub  three  1  4  4
# 3   yuvi    one  4  0  2
# 4  rithi  three  1  4  0
# 5  sangu    two  3  3  2
#
# Summary of aggregate functions using describe()
#                C         D         E
# count  6.000000  6.000000  6.000000
# mean   1.500000  2.500000  1.333333
# std    1.643168  1.643168  1.632993
# min    0.000000  0.000000  0.000000
# 25%    0.250000  1.500000  0.000000
# 50%    1.000000  3.000000  1.000000
# 75%    2.500000  3.750000  2.000000
# max    4.000000  4.000000  4.000000
